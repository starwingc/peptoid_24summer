# %% [markdown]
# # This notebook comparing the GAFF1 modelling data with the experimental value, taking the input from clustering.ipynb, in which all the results are in sampling/

# %%
import biceps 

import mdtraj as md
import numpy as np
import pandas as pd 
import os, pickle, string, shutil 
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings('ignore', category=FutureWarning)

# %% [markdown]
# ### Prepare NOE Distance

# %%
def compute_ensemble_avg_NOE(grouped_files, indices, outdir, verbose=False):
    indices = np_ind_noe
    for i, state in enumerate(grouped_files):
        for j, frame in enumerate(state):
            d = md.compute_distances(md.load(frame), indices) * 10. # convert nm to Å
        data = np.mean(d, axis=0)
        data = data.reshape(1, -1) # Reshape the data to have the shape (1, 8) instead of (8,)
        np.savetxt(f'{outdir}NOE_{i}.txt', data)
        print(f"save model NOE to: {outdir}NOE_{i}.txt ")

# %%
import os
import shutil

# Define the root directory
root = 'biceps/'

# Check if the directory exists
if os.path.exists(root):
    # Clear the contents if the directory exists
    shutil.rmtree(root)  # Remove the directory and its contents
    os.makedirs(root)    # Recreate the empty directory
    print(f"All content in '{root}' has been cleared ")
else:
    # Create the directory if it doesn't exist
    os.makedirs(root)
    print(f"'{root}' has been created.")
# Out:
# All content in 'biceps/' has been cleared

# %%
'''
atom1 - atom 2 | state - noe experiment distance

25, 26 - 58, 59 | 1 - 3.5
84, 85 - 125, 126 | 2 - 3.5
150, 151 - 184, 185 |  3-  3.5
204, 205 - 229, 230 | 4 - 3.5
250, 251 - 284, 285 | 5 - 3.5
202, 198, 197, 203 - 271, 272, 273, 274, 275, 276, 278, 279, 280, 281, 282, 283 | 6 - 4.5
244, 248 - 181, 182, 183, 171, 172, 173, 176, 177, 178 | 7 - 4.5
141, 145, 149 - 220, 221, 222, 223, 224, 225, 226, 227, 228| 8 - 4.5
141, 149 - 117, 118, 119, 122, 123, 124 | 9 - 4.5
16, 20, 24 - 117, 118, 119, 122, 123, 124 | 10 - 4.5
245, 246, 247 - 181, 182, 183, 171, 172, 173, 176, 177, 178 | 11 - 4.5
199, 200, 201 - 271, 272, 273, 274, 275, 276, 278, 279, 280, 281, 282, 283 | 12 - 4.5
17, 18, 19, 21, 22, 23 - 117, 118, 119, 122, 123, 124 | 13 - 4.5
'''
# Out:
# '\natom1 - atom 2 | state - noe experiment distance\n\n25, 26 - 58, 59 | 1 - 3.5\n84, 85 - 125, 126 | 2 - 3.5\n150, 151 - 184, 185 |  3-  3.5\n204, 205 - 229, 230 | 4 - 3.5\n250, 251 - 284, 285 | 5 - 3.5\n202, 198, 197, 203 - 271, 272, 273, 274, 275, 276, 278, 279, 280, 281, 282, 283 | 6 - 4.5\n244, 248 - 181, 182, 183, 171, 172, 173, 176, 177, 178 | 7 - 4.5\n141, 145, 149 - 220, 221, 222, 223, 224, 225, 226, 227, 228| 8 - 4.5\n141, 149 - 117, 118, 119, 122, 123, 124 | 9 - 4.5\n16, 20, 24 - 117, 118, 119, 122, 123, 124 | 10 - 4.5\n245, 246, 247 - 181, 182, 183, 171, 172, 173, 176, 177, 178 | 11 - 4.5\n199, 200, 201 - 271, 272, 273, 274, 275, 276, 278, 279, 280, 281, 282, 283 | 12 - 4.5\n17, 18, 19, 21, 22, 23 - 117, 118, 119, 122, 123, 124 | 13 - 4.5\n'

# %%
# Store the Modeling and Experiment data NEO  
data_dir = 'biceps/data/'
biceps.toolbox.mkdir(data_dir)

# Define the atom pair indices for noe distance 
atom_indices = [
    [25, 58], [25, 59], [26, 58], [26, 59],
    
    [84, 125], [84, 126], [85, 125], [85, 126],
    
    [150, 184], [150, 185], [151, 184], [151, 185],
    
    [204, 229], [204, 230], [205, 229], [205, 230],
    
    [250, 284], [250, 285], [251, 284], [251, 285],
    
    [202, 271], [202, 272], [202, 273], [202, 274], [202, 275], [202, 276], [202, 278], [202, 279], [202, 280], [202, 281], [202, 282], [202, 283],
    [198, 271], [198, 272], [198, 273], [198, 274], [198, 275], [198, 276], [198, 278], [198, 279], [198, 280], [198, 281], [198, 282], [198, 283],
    [197, 271], [197, 272], [197, 273], [197, 274], [197, 275], [197, 276], [197, 278], [197, 279], [197, 280], [197, 281], [197, 282], [197, 283],
    [203, 271], [203, 272], [203, 273], [203, 274], [203, 275], [203, 276], [203, 278], [203, 279], [203, 280], [203, 281], [203, 282], [203, 283],
    
    [244, 181], [244, 182], [244, 183], [244, 171], [244, 172], [244, 173], [244, 176], [244, 177], [244, 178],
    [248, 181], [248, 182], [248, 183], [248, 171], [248, 172], [248, 173], [248, 176], [248, 177], [248, 178],
    
    [141, 220], [141, 221], [141, 222], [141, 223], [141, 224], [141, 225], [141, 226], [141, 227], [141, 228],
    [145, 220], [145, 221], [145, 222], [145, 223], [145, 224], [145, 225], [145, 226], [145, 227], [145, 228],
    [149, 220], [149, 221], [149, 222], [149, 223], [149, 224], [149, 225], [149, 226], [149, 227], [149, 228],
    
    [141, 117], [141, 118], [141, 119], [141, 122], [141, 123], [141, 124],
    [149, 117], [149, 118], [149, 119], [149, 122], [149, 123], [149, 124],
    
    [16, 117], [16, 118], [16, 119], [16, 122], [16, 123], [16, 124],
    [20, 117], [20, 118], [20, 119], [20, 122], [20, 123], [20, 124],
    [24, 117], [24, 118], [24, 119], [24, 122], [24, 123], [24, 124],
    
    [245, 181], [245, 182], [245, 183], [245, 171], [245, 172], [245, 173], [245, 176], [245, 177], [245, 178],
    [246, 181], [246, 182], [246, 183], [246, 171], [246, 172], [246, 173], [246, 176], [246, 177], [246, 178],
    [247, 181], [247, 182], [247, 183], [247, 171], [247, 172], [247, 173], [247, 176], [247, 177], [247, 178],
    
    [199, 271], [199, 272], [199, 273], [199, 274], [199, 275], [199, 276], [199, 278], [199, 279], [199, 280], [199, 281], [199, 282], [199, 283],
    [200, 271], [200, 272], [200, 273], [200, 274], [200, 275], [200, 276], [200, 278], [200, 279], [200, 280], [200, 281], [200, 282], [200, 283],
    [201, 271], [201, 272], [201, 273], [201, 274], [201, 275], [201, 276], [201, 278], [201, 279], [201, 280], [201, 281], [201, 282], [201, 283],
    
    [17, 117], [17, 118], [17, 119], [17, 122], [17, 123], [17, 124],
    [18, 117], [18, 118], [18, 119], [18, 122], [18, 123], [18, 124],
    [19, 117], [19, 118], [19, 119], [19, 122], [19, 123], [19, 124],
    [21, 117], [21, 118], [21, 119], [21, 122], [21, 123], [21, 124],
    [22, 117], [22, 118], [22, 119], [22, 122], [22, 123], [22, 124],
    [23, 117], [23, 118], [23, 119], [23, 122], [23, 123], [23, 124]
]



with open(f"{data_dir}atom_indice_noe.txt", 'w') as file:
    for pair in atom_indices:
        line = f"{pair[0]} {pair[1]}\n"
        file.write(line)

#recorded experimental state, and experimental NOE distance
exp_state_noe = [
    [1, 3.5], [1, 3.5], [1, 3.5], [1, 3.5],
    
    [2, 3.5], [2, 3.5], [2, 3.5], [2, 3.5],
    
    [3, 3.5], [3, 3.5], [3, 3.5], [3, 3.5],
    
    [4, 3.5], [4, 3.5], [4, 3.5], [4, 3.5],
    
    [5, 3.5], [5, 3.5], [5, 3.5], [5, 3.5],
    
    [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5],
    [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5],
    [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5],
    [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5], [6, 4.5],
    
    [7, 4.5], [7, 4.5], [7, 4.5], [7, 4.5], [7, 4.5], [7, 4.5], [7, 4.5], [7, 4.5], [7, 4.5],
    [7, 4.5], [7, 4.5], [7, 4.5], [7, 4.5], [7, 4.5], [7, 4.5], [7, 4.5], [7, 4.5], [7, 4.5],
    
    [8, 4.5], [8, 4.5], [8, 4.5], [8, 4.5], [8, 4.5], [8, 4.5], [8, 4.5], [8, 4.5], [8, 4.5],
    [8, 4.5], [8, 4.5], [8, 4.5], [8, 4.5], [8, 4.5], [8, 4.5], [8, 4.5], [8, 4.5], [8, 4.5],
    [8, 4.5], [8, 4.5], [8, 4.5], [8, 4.5], [8, 4.5], [8, 4.5], [8, 4.5], [8, 4.5], [8, 4.5],
    
    [9, 4.5], [9, 4.5], [9, 4.5], [9, 4.5], [9, 4.5], [9, 4.5],
    [9, 4.5], [9, 4.5], [9, 4.5], [9, 4.5], [9, 4.5], [9, 4.5],
    
    [10, 4.5], [10, 4.5], [10, 4.5], [10, 4.5], [10, 4.5], [10, 4.5],
    [10, 4.5], [10, 4.5], [10, 4.5], [10, 4.5], [10, 4.5], [10, 4.5],
    [10, 4.5], [10, 4.5], [10, 4.5], [10, 4.5], [10, 4.5], [10, 4.5],
    
    [11, 4.5], [11, 4.5], [11, 4.5], [11, 4.5], [11, 4.5], [11, 4.5], [11, 4.5], [11, 4.5], [11, 4.5],
    [11, 4.5], [11, 4.5], [11, 4.5], [11, 4.5], [11, 4.5], [11, 4.5], [11, 4.5], [11, 4.5], [11, 4.5],
    [11, 4.5], [11, 4.5], [11, 4.5], [11, 4.5], [11, 4.5], [11, 4.5], [11, 4.5], [11, 4.5], [11, 4.5],
    
    [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5],
    [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5],
    [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5], [12, 4.5],
    
    [13, 4.5], [13, 4.5], [13, 4.5], [13, 4.5], [13, 4.5], [13, 4.5],
    [13, 4.5], [13, 4.5], [13, 4.5], [13, 4.5], [13, 4.5], [13, 4.5],
    [13, 4.5], [13, 4.5], [13, 4.5], [13, 4.5], [13, 4.5], [13, 4.5],
    [13, 4.5], [13, 4.5], [13, 4.5], [13, 4.5], [13, 4.5], [13, 4.5],
    [13, 4.5], [13, 4.5], [13, 4.5], [13, 4.5], [13, 4.5], [13, 4.5],
    [13, 4.5], [13, 4.5], [13, 4.5], [13, 4.5], [13, 4.5], [13, 4.5]
]


with open(f"{data_dir}noe_distance.txt", 'w') as file:
    for pair in exp_state_noe:
        line = f"{pair[0]} {pair[1]}\n"
        file.write(line)

# %%
outdir = 'biceps/_NOE/'
biceps.toolbox.mkdir(outdir)


# Create a grouped_file list 
grouped_files = []
skipped_cluster = []
ncluster = 43

for cluster in range(ncluster):
    sample_path = f"sampling/sample_state_0_cluster{cluster}_whole.pdb"
    sample = [f"sampling/sample_state_0_cluster{cluster}_whole.pdb"]
    if os.path.exists(sample_path):
        grouped_files.append(sample)
    else:
        skipped_cluster.append(cluster)
        print(f"File {sample} does not exist. Skipping cluster {cluster}.") 
#print(grouped_files)

# Create a index file for atomic indice and noe distance 
gmx_ind_noe = np.loadtxt(f"{data_dir}atom_indice_noe.txt")
#print(gmx_ind_noe)

if (type(gmx_ind_noe) != np.ndarray and type(gmx_ind_noe) != list):
    print(type(gmx_ind_noe))
np_ind_noe = gmx_ind_noe -1 #indices of numpy is indices of gmx - 1 
#print(np_ind_noe)
indices = np_ind_noe

# Compute the average NOE distance of samplings in each states (cluters) 
compute_ensemble_avg_NOE(grouped_files, indices, outdir)    

model_data_NOE = np.array([np.loadtxt(file) for file in biceps.toolbox.get_files(f"{outdir}*.txt")])
print(model_data_NOE)
exp_data_NOE = np.loadtxt(f"{data_dir}noe_distance.txt")

print(model_data_NOE.shape)
print(skipped_cluster)
# Out:
# save model NOE to: biceps/_NOE/NOE_0.txt
# save model NOE to: biceps/_NOE/NOE_1.txt
# save model NOE to: biceps/_NOE/NOE_2.txt
# save model NOE to: biceps/_NOE/NOE_3.txt
# save model NOE to: biceps/_NOE/NOE_4.txt
# save model NOE to: biceps/_NOE/NOE_5.txt
# save model NOE to: biceps/_NOE/NOE_6.txt
# save model NOE to: biceps/_NOE/NOE_7.txt
# save model NOE to: biceps/_NOE/NOE_8.txt
# save model NOE to: biceps/_NOE/NOE_9.txt
# save model NOE to: biceps/_NOE/NOE_10.txt
# save model NOE to: biceps/_NOE/NOE_11.txt
# save model NOE to: biceps/_NOE/NOE_12.txt
# save model NOE to: biceps/_NOE/NOE_13.txt
# save model NOE to: biceps/_NOE/NOE_14.txt
# save model NOE to: biceps/_NOE/NOE_15.txt
# save model NOE to: biceps/_NOE/NOE_16.txt
# save model NOE to: biceps/_NOE/NOE_17.txt
# save model NOE to: biceps/_NOE/NOE_18.txt
# save model NOE to: biceps/_NOE/NOE_19.txt
# save model NOE to: biceps/_NOE/NOE_20.txt
# save model NOE to: biceps/_NOE/NOE_21.txt
# save model NOE to: biceps/_NOE/NOE_22.txt
# save model NOE to: biceps/_NOE/NOE_23.txt
# save model NOE to: biceps/_NOE/NOE_24.txt
# save model NOE to: biceps/_NOE/NOE_25.txt
# save model NOE to: biceps/_NOE/NOE_26.txt
# save model NOE to: biceps/_NOE/NOE_27.txt
# save model NOE to: biceps/_NOE/NOE_28.txt
# save model NOE to: biceps/_NOE/NOE_29.txt
# save model NOE to: biceps/_NOE/NOE_30.txt
# save model NOE to: biceps/_NOE/NOE_31.txt
# save model NOE to: biceps/_NOE/NOE_32.txt
# save model NOE to: biceps/_NOE/NOE_33.txt
# save model NOE to: biceps/_NOE/NOE_34.txt
# save model NOE to: biceps/_NOE/NOE_35.txt
# save model NOE to: biceps/_NOE/NOE_36.txt
# save model NOE to: biceps/_NOE/NOE_37.txt
# save model NOE to: biceps/_NOE/NOE_38.txt
# save model NOE to: biceps/_NOE/NOE_39.txt
# save model NOE to: biceps/_NOE/NOE_40.txt
# save model NOE to: biceps/_NOE/NOE_41.txt
# save model NOE to: biceps/_NOE/NOE_42.txt
# [[ 5.01187086  4.56805611  4.76593256 ... 13.2199831  13.63093567
#   13.02561092]
#  [ 5.09930801  4.66901636  4.72762203 ... 14.33391094 13.01742458
#   13.75049114]
#  [ 4.83908701  4.56858206  4.6780386  ... 12.22745132 12.98974133
#   12.66672897]
#  ...
#  [ 4.22310781  4.54235792  4.48105097 ... 10.20513058 10.31148052
#   10.97482014]
#  [ 2.96552372  4.20425558  2.17083645 ... 10.05290699 10.40764141
#    9.91480637]
#  [ 4.52877188  4.72245264  4.72323084 ... 17.84211731 17.45379066
#   17.72157478]]
# (43, 242)
# []

# %%
outdir = 'biceps/NOE/'
biceps.toolbox.mkdir(outdir)
nstates = model_data_NOE.shape[0] 

prep = biceps.Preparation(nstates=nstates, outdir=outdir) # nstate = number of cluster for sampling 
prep.prepare_noe(exp_data_NOE, model_data_NOE, indices = np_ind_noe, verbose=True)
# Out:
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   5.011871                1           24           57
# 1    3.5   4.568056                1           24           58
# 2    3.5   4.765933                1           25           57
# 3    3.5   4.463550                1           25           58
# 4    3.5   4.798771                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  13.532485               13           22          117
# 238  4.5  13.390489               13           22          118
# 239  4.5  13.219983               13           22          121
# 240  4.5  13.630936               13           22          122
# 241  4.5  13.025611               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/0.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   5.099308                1           24           57
# 1    3.5   4.669016                1           24           58
# 2    3.5   4.727622                1           25           57
# 3    3.5   4.830334                1           25           58
# 4    3.5   4.781479                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  13.646848               13           22          117
# 238  4.5  13.502785               13           22          118
# 239  4.5  14.333911               13           22          121
# 240  4.5  13.017425               13           22          122
# 241  4.5  13.750491               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/1.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   4.839087                1           24           57
# 1    3.5   4.568582                1           24           58
# 2    3.5   4.678039                1           25           57
# 3    3.5   4.393686                1           25           58
# 4    3.5   4.801259                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  14.388184               13           22          117
# 238  4.5  15.104833               13           22          118
# 239  4.5  12.227451               13           22          121
# 240  4.5  12.989741               13           22          122
# 241  4.5  12.666729               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/2.noe as pickle...
#      exp     model  restraint_index  atom_index1  atom_index2
# 0    3.5  4.656264                1           24           57
# 1    3.5  4.635511                1           24           58
# 2    3.5  4.805923                1           25           57
# 3    3.5  4.621977                1           25           58
# 4    3.5  2.721169                2           83          124
# ..   ...       ...              ...          ...          ...
# 237  4.5  9.348806               13           22          117
# 238  4.5  8.053849               13           22          118
# 239  4.5  9.481380               13           22          121
# 240  4.5  9.517803               13           22          122
# 241  4.5  9.669075               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/3.noe as pickle...
#      exp     model  restraint_index  atom_index1  atom_index2
# 0    3.5  4.810077                1           24           57
# 1    3.5  4.653246                1           24           58
# 2    3.5  4.790955                1           25           57
# 3    3.5  4.550715                1           25           58
# 4    3.5  4.748106                2           83          124
# ..   ...       ...              ...          ...          ...
# 237  4.5  7.023729               13           22          117
# 238  4.5  7.719170               13           22          118
# 239  4.5  7.467365               13           22          121
# 240  4.5  7.484512               13           22          122
# 241  4.5  7.477602               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/4.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   4.704020                1           24           57
# 1    3.5   4.656181                1           24           58
# 2    3.5   4.717231                1           25           57
# 3    3.5   4.408996                1           25           58
# 4    3.5   4.744841                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  10.922801               13           22          117
# 238  4.5  10.745842               13           22          118
# 239  4.5  11.344444               13           22          121
# 240  4.5  11.365936               13           22          122
# 241  4.5  11.115510               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/5.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   4.957218                1           24           57
# 1    3.5   4.687889                1           24           58
# 2    3.5   4.602667                1           25           57
# 3    3.5   4.223435                1           25           58
# 4    3.5   3.762495                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  11.152404               13           22          117
# 238  4.5  10.736730               13           22          118
# 239  4.5   8.626513               13           22          121
# 240  4.5   9.516541               13           22          122
# 241  4.5   8.886926               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/6.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   4.268148                1           24           57
# 1    3.5   4.598871                1           24           58
# 2    3.5   2.937288                1           25           57
# 3    3.5   3.261040                1           25           58
# 4    3.5   4.857292                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5   9.437883               13           22          117
# 238  4.5   9.830876               13           22          118
# 239  4.5  12.807678               13           22          121
# 240  4.5  13.221753               13           22          122
# 241  4.5  13.214513               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/7.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   4.848569                1           24           57
# 1    3.5   4.444111                1           24           58
# 2    3.5   4.625542                1           25           57
# 3    3.5   4.517350                1           25           58
# 4    3.5   4.814607                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5   9.628842               13           22          117
# 238  4.5   9.564137               13           22          118
# 239  4.5  10.625614               13           22          121
# 240  4.5  10.528409               13           22          122
# 241  4.5   9.982864               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/8.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   3.788725                1           24           57
# 1    3.5   3.148925                1           24           58
# 2    3.5   3.396214                1           25           57
# 3    3.5   2.974792                1           25           58
# 4    3.5   4.892336                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  13.896642               13           22          117
# 238  4.5  13.456474               13           22          118
# 239  4.5  15.321845               13           22          121
# 240  4.5  16.090994               13           22          122
# 241  4.5  15.381185               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/9.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   4.662240                1           24           57
# 1    3.5   4.698314                1           24           58
# 2    3.5   4.764784                1           25           57
# 3    3.5   4.552999                1           25           58
# 4    3.5   2.675759                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  12.109208               13           22          117
# 238  4.5  12.198470               13           22          118
# 239  4.5   9.154895               13           22          121
# 240  4.5   9.871846               13           22          122
# 241  4.5   9.188796               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/10.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   4.968058                1           24           57
# 1    3.5   4.627719                1           24           58
# 2    3.5   4.747758                1           25           57
# 3    3.5   4.796058                1           25           58
# 4    3.5   4.999027                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  15.141187               13           22          117
# 238  4.5  15.220013               13           22          118
# 239  4.5  13.839396               13           22          121
# 240  4.5  14.689723               13           22          122
# 241  4.5  14.334106               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/11.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   4.761970                1           24           57
# 1    3.5   4.416742                1           24           58
# 2    3.5   4.226105                1           25           57
# 3    3.5   4.358448                1           25           58
# 4    3.5   4.901057                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  15.260135               13           22          117
# 238  4.5  15.741600               13           22          118
# 239  4.5  12.607754               13           22          121
# 240  4.5  12.892403               13           22          122
# 241  4.5  12.727544               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/12.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   4.574454                1           24           57
# 1    3.5   4.694174                1           24           58
# 2    3.5   4.666133                1           25           57
# 3    3.5   4.886285                1           25           58
# 4    3.5   2.580083                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  12.764766               13           22          117
# 238  4.5  12.677060               13           22          118
# 239  4.5  10.247741               13           22          121
# 240  4.5  10.425584               13           22          122
# 241  4.5  10.042518               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/13.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   2.529693                1           24           57
# 1    3.5   3.815915                1           24           58
# 2    3.5   2.608099                1           25           57
# 3    3.5   4.162461                1           25           58
# 4    3.5   4.930241                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5   8.729236               13           22          117
# 238  4.5   8.646323               13           22          118
# 239  4.5  11.097554               13           22          121
# 240  4.5  10.456310               13           22          122
# 241  4.5  10.802558               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/14.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   4.830136                1           24           57
# 1    3.5   4.692028                1           24           58
# 2    3.5   4.601286                1           25           57
# 3    3.5   4.289612                1           25           58
# 4    3.5   2.309132                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  10.898582               13           22          117
# 238  4.5  10.031862               13           22          118
# 239  4.5  10.810818               13           22          121
# 240  4.5   9.709372               13           22          122
# 241  4.5   9.121446               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/15.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   3.500781                1           24           57
# 1    3.5   3.102965                1           24           58
# 2    3.5   3.274579                1           25           57
# 3    3.5   2.693576                1           25           58
# 4    3.5   2.593442                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  12.525387               13           22          117
# 238  4.5  13.094087               13           22          118
# 239  4.5  10.409213               13           22          121
# 240  4.5  11.160928               13           22          122
# 241  4.5  11.632686               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/16.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   2.127990                1           24           57
# 1    3.5   3.507550                1           24           58
# 2    3.5   3.172692                1           25           57
# 3    3.5   4.391087                1           25           58
# 4    3.5   4.931044                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  12.214801               13           22          117
# 238  4.5  11.615560               13           22          118
# 239  4.5  11.969544               13           22          121
# 240  4.5  11.991834               13           22          122
# 241  4.5  12.720726               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/17.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   2.921684                1           24           57
# 1    3.5   3.375168                1           24           58
# 2    3.5   3.354178                1           25           57
# 3    3.5   3.570303                1           25           58
# 4    3.5   2.898530                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  11.131759               13           22          117
# 238  4.5  10.215766               13           22          118
# 239  4.5  12.824365               13           22          121
# 240  4.5  13.920058               13           22          122
# 241  4.5  13.487747               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/18.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   4.597579                1           24           57
# 1    3.5   4.627414                1           24           58
# 2    3.5   4.311374                1           25           57
# 3    3.5   4.518734                1           25           58
# 4    3.5   5.021740                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  11.934499               13           22          117
# 238  4.5  13.128659               13           22          118
# 239  4.5  13.974294               13           22          121
# 240  4.5  13.608943               13           22          122
# 241  4.5  13.930224               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/19.noe as pickle...
#      exp     model  restraint_index  atom_index1  atom_index2
# 0    3.5  3.807317                1           24           57
# 1    3.5  2.356743                1           24           58
# 2    3.5  3.915621                1           25           57
# 3    3.5  2.560693                1           25           58
# 4    3.5  2.419729                2           83          124
# ..   ...       ...              ...          ...          ...
# 237  4.5  6.661793               13           22          117
# 238  4.5  6.130751               13           22          118
# 239  4.5  4.258626               13           22          121
# 240  4.5  4.446456               13           22          122
# 241  4.5  4.252393               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/20.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   3.062028                1           24           57
# 1    3.5   2.883776                1           24           58
# 2    3.5   4.276326                1           25           57
# 3    3.5   3.873030                1           25           58
# 4    3.5   5.064755                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  14.556884               13           22          117
# 238  4.5  14.753983               13           22          118
# 239  4.5  13.225963               13           22          121
# 240  4.5  13.915709               13           22          122
# 241  4.5  13.663293               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/21.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   2.165195                1           24           57
# 1    3.5   3.722578                1           24           58
# 2    3.5   3.316726                1           25           57
# 3    3.5   4.654203                1           25           58
# 4    3.5   2.674642                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  11.564389               13           22          117
# 238  4.5  11.069660               13           22          118
# 239  4.5  12.006835               13           22          121
# 240  4.5  12.069087               13           22          122
# 241  4.5  12.239396               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/22.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   3.457832                1           24           57
# 1    3.5   2.850913                1           24           58
# 2    3.5   3.447223                1           25           57
# 3    3.5   3.103444                1           25           58
# 4    3.5   4.895821                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  12.871427               13           22          117
# 238  4.5  12.143733               13           22          118
# 239  4.5  12.254745               13           22          121
# 240  4.5  11.929793               13           22          122
# 241  4.5  12.855987               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/23.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   3.115523                1           24           57
# 1    3.5   4.412074                1           24           58
# 2    3.5   2.471557                1           25           57
# 3    3.5   3.927506                1           25           58
# 4    3.5   2.262496                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  11.694068               13           22          117
# 238  4.5  11.135985               13           22          118
# 239  4.5  13.544529               13           22          121
# 240  4.5  13.107718               13           22          122
# 241  4.5  13.446457               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/24.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   3.822155                1           24           57
# 1    3.5   2.277708                1           24           58
# 2    3.5   4.284266                1           25           57
# 3    3.5   2.987592                1           25           58
# 4    3.5   2.914375                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  15.189633               13           22          117
# 238  4.5  15.129552               13           22          118
# 239  4.5  13.909508               13           22          121
# 240  4.5  14.821477               13           22          122
# 241  4.5  14.602376               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/25.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   2.511290                1           24           57
# 1    3.5   3.780915                1           24           58
# 2    3.5   3.136845                1           25           57
# 3    3.5   4.449567                1           25           58
# 4    3.5   4.963305                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  14.237370               13           22          117
# 238  4.5  14.217072               13           22          118
# 239  4.5  11.871308               13           22          121
# 240  4.5  10.630822               13           22          122
# 241  4.5  11.459729               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/26.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   2.725560                1           24           57
# 1    3.5   3.953692                1           24           58
# 2    3.5   2.278744                1           25           57
# 3    3.5   3.888083                1           25           58
# 4    3.5   4.929842                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  15.110480               13           22          117
# 238  4.5  14.842437               13           22          118
# 239  4.5  11.126813               13           22          121
# 240  4.5  12.743619               13           22          122
# 241  4.5  12.463409               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/27.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   2.729195                1           24           57
# 1    3.5   3.851018                1           24           58
# 2    3.5   2.256932                1           25           57
# 3    3.5   3.769671                1           25           58
# 4    3.5   2.303364                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5   8.802169               13           22          117
# 238  4.5   9.386001               13           22          118
# 239  4.5  14.636958               13           22          121
# 240  4.5  14.475388               13           22          122
# 241  4.5  14.689934               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/28.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   2.179940                1           24           57
# 1    3.5   3.690176                1           24           58
# 2    3.5   2.819782                1           25           57
# 3    3.5   4.273044                1           25           58
# 4    3.5   4.893775                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5   9.894341               13           22          117
# 238  4.5   9.995037               13           22          118
# 239  4.5   9.541711               13           22          121
# 240  4.5  10.014377               13           22          122
# 241  4.5   9.384056               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/29.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   4.470264                1           24           57
# 1    3.5   4.736972                1           24           58
# 2    3.5   4.830598                1           25           57
# 3    3.5   4.802212                1           25           58
# 4    3.5   2.806360                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  18.812265               13           22          117
# 238  4.5  18.403540               13           22          118
# 239  4.5  17.539547               13           22          121
# 240  4.5  16.929855               13           22          122
# 241  4.5  18.524549               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/30.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   4.753133                1           24           57
# 1    3.5   4.926195                1           24           58
# 2    3.5   4.560765                1           25           57
# 3    3.5   4.658937                1           25           58
# 4    3.5   2.532533                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  11.030751               13           22          117
# 238  4.5  11.113814               13           22          118
# 239  4.5  11.456337               13           22          121
# 240  4.5  11.619057               13           22          122
# 241  4.5  10.295296               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/31.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   4.607065                1           24           57
# 1    3.5   5.040563                1           24           58
# 2    3.5   4.630291                1           25           57
# 3    3.5   4.744987                1           25           58
# 4    3.5   5.058007                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  14.021717               13           22          117
# 238  4.5  12.930740               13           22          118
# 239  4.5  13.992634               13           22          121
# 240  4.5  13.895786               13           22          122
# 241  4.5  13.623843               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/32.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   2.498839                1           24           57
# 1    3.5   3.749204                1           24           58
# 2    3.5   2.873313                1           25           57
# 3    3.5   4.184488                1           25           58
# 4    3.5   4.951148                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  13.105189               13           22          117
# 238  4.5  12.165771               13           22          118
# 239  4.5  12.568600               13           22          121
# 240  4.5  12.529216               13           22          122
# 241  4.5  13.303775               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/33.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   2.655422                1           24           57
# 1    3.5   3.990372                1           24           58
# 2    3.5   2.279205                1           25           57
# 3    3.5   3.778672                1           25           58
# 4    3.5   2.515341                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  13.742160               13           22          117
# 238  4.5  12.832013               13           22          118
# 239  4.5  15.322220               13           22          121
# 240  4.5  15.596603               13           22          122
# 241  4.5  14.911040               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/34.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   2.165964                1           24           57
# 1    3.5   3.524783                1           24           58
# 2    3.5   3.669839                1           25           57
# 3    3.5   4.752200                1           25           58
# 4    3.5   4.953967                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  15.792560               13           22          117
# 238  4.5  15.024254               13           22          118
# 239  4.5  14.043892               13           22          121
# 240  4.5  13.286614               13           22          122
# 241  4.5  12.321033               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/35.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   2.580485                1           24           57
# 1    3.5   3.825346                1           24           58
# 2    3.5   2.919461                1           25           57
# 3    3.5   4.336812                1           25           58
# 4    3.5   4.865096                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5   9.770864               13           22          117
# 238  4.5   9.774058               13           22          118
# 239  4.5   9.833511               13           22          121
# 240  4.5  10.149201               13           22          122
# 241  4.5  10.009070               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/36.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   4.264125                1           24           57
# 1    3.5   4.936816                1           24           58
# 2    3.5   4.568737                1           25           57
# 3    3.5   4.790903                1           25           58
# 4    3.5   3.074657                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  14.849899               13           22          117
# 238  4.5  15.204656               13           22          118
# 239  4.5  15.078327               13           22          121
# 240  4.5  15.448341               13           22          122
# 241  4.5  14.888940               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/37.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   3.254708                1           24           57
# 1    3.5   2.739324                1           24           58
# 2    3.5   3.425688                1           25           57
# 3    3.5   3.076906                1           25           58
# 4    3.5   3.344501                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  12.581601               13           22          117
# 238  4.5  13.623052               13           22          118
# 239  4.5  13.340695               13           22          121
# 240  4.5  12.816887               13           22          122
# 241  4.5  14.306354               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/38.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   3.847552                1           24           57
# 1    3.5   3.284471                1           24           58
# 2    3.5   3.692879                1           25           57
# 3    3.5   3.282847                1           25           58
# 4    3.5   2.036937                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  13.544194               13           22          117
# 238  4.5  14.501729               13           22          118
# 239  4.5  11.561600               13           22          121
# 240  4.5  11.344037               13           22          122
# 241  4.5  11.267036               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/39.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   4.223108                1           24           57
# 1    3.5   4.542358                1           24           58
# 2    3.5   4.481051                1           25           57
# 3    3.5   4.751202                1           25           58
# 4    3.5   3.096989                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  10.848098               13           22          117
# 238  4.5  10.713230               13           22          118
# 239  4.5  10.205131               13           22          121
# 240  4.5  10.311481               13           22          122
# 241  4.5  10.974820               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/40.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   2.965524                1           24           57
# 1    3.5   4.204256                1           24           58
# 2    3.5   2.170836                1           25           57
# 3    3.5   3.650663                1           25           58
# 4    3.5   3.006680                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5   8.077154               13           22          117
# 238  4.5   7.922693               13           22          118
# 239  4.5  10.052907               13           22          121
# 240  4.5  10.407641               13           22          122
# 241  4.5   9.914806               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/41.noe as pickle...
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   4.528772                1           24           57
# 1    3.5   4.722453                1           24           58
# 2    3.5   4.723231                1           25           57
# 3    3.5   5.009031                1           25           58
# 4    3.5   3.088352                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  15.514702               13           22          117
# 238  4.5  15.907379               13           22          118
# 239  4.5  17.842117               13           22          121
# 240  4.5  17.453791               13           22          122
# 241  4.5  17.721575               13           22          123
#
# [242 rows x 5 columns]
# Writing biceps/NOE/42.noe as pickle...

# %%
input_data = prep.to_sorted_list()
print(input_data)
# Out:
# [['biceps/NOE/0.noe'], ['biceps/NOE/1.noe'], ['biceps/NOE/2.noe'], ['biceps/NOE/3.noe'], ['biceps/NOE/4.noe'], ['biceps/NOE/5.noe'], ['biceps/NOE/6.noe'], ['biceps/NOE/7.noe'], ['biceps/NOE/8.noe'], ['biceps/NOE/9.noe'], ['biceps/NOE/10.noe'], ['biceps/NOE/11.noe'], ['biceps/NOE/12.noe'], ['biceps/NOE/13.noe'], ['biceps/NOE/14.noe'], ['biceps/NOE/15.noe'], ['biceps/NOE/16.noe'], ['biceps/NOE/17.noe'], ['biceps/NOE/18.noe'], ['biceps/NOE/19.noe'], ['biceps/NOE/20.noe'], ['biceps/NOE/21.noe'], ['biceps/NOE/22.noe'], ['biceps/NOE/23.noe'], ['biceps/NOE/24.noe'], ['biceps/NOE/25.noe'], ['biceps/NOE/26.noe'], ['biceps/NOE/27.noe'], ['biceps/NOE/28.noe'], ['biceps/NOE/29.noe'], ['biceps/NOE/30.noe'], ['biceps/NOE/31.noe'], ['biceps/NOE/32.noe'], ['biceps/NOE/33.noe'], ['biceps/NOE/34.noe'], ['biceps/NOE/35.noe'], ['biceps/NOE/36.noe'], ['biceps/NOE/37.noe'], ['biceps/NOE/38.noe'], ['biceps/NOE/39.noe'], ['biceps/NOE/40.noe'], ['biceps/NOE/41.noe'], ['biceps/NOE/42.noe']]

# %%
pd.read_pickle(input_data[0][0])
# Out:
#      exp      model  restraint_index  atom_index1  atom_index2
# 0    3.5   5.011871                1           24           57
# 1    3.5   4.568056                1           24           58
# 2    3.5   4.765933                1           25           57
# 3    3.5   4.463550                1           25           58
# 4    3.5   4.798771                2           83          124
# ..   ...        ...              ...          ...          ...
# 237  4.5  13.532485               13           22          117
# 238  4.5  13.390489               13           22          118
# 239  4.5  13.219983               13           22          121
# 240  4.5  13.630936               13           22          122
# 241  4.5  13.025611               13           22          123
#
# [242 rows x 5 columns]

# %% [markdown]
# ### Prepare Energy

# %%
# Convert the Probability into Reduced Free Energy 
np_skipped_cluster = np.array(skipped_cluster) - 1
print(np_skipped_cluster)
P = np.loadtxt('sampling/clusters_probability.dat') / 100
#P_filtered = np.delete(P, np_skipped_cluster)
#P = P_filtered / P_filtered.sum()
print(P, P.shape, P.sum(), P.max(), np.argmax(P))

k_B = 1.38e-23  # Boltzmann constant (j/K)
T = 300  # (K)
energies = -np.log(P) # Calculate reduced free energy E using the equation E = ln(P) (KT)
energies -= energies.min() # set ground state to zero, just in case
print(f"Reduced Free Energy F: {energies} KT")

####### Data and Output Directories #######

# REQUIRED: specify directory of input data (BICePs readable format)
input_data = biceps.toolbox.sort_data('biceps/NOE/')

# REQUIRED: specify outcome directory of BICePs sampling
outdir = 'biceps/results/'
# Make a new directory if we have to
biceps.toolbox.mkdir(outdir)
# Out:
# []
# [2.06659778e-02 9.66634446e-03 1.99993334e-04 8.99970001e-04
#  3.36655445e-03 6.36645445e-03 1.56661445e-03 9.06636445e-03
#  3.36655445e-03 1.26662445e-03 7.09976334e-03 1.30328989e-02
#  1.13329556e-02 7.16642779e-03 5.17982734e-02 1.26662445e-03
#  2.33992200e-02 7.23309223e-03 1.89327022e-02 3.99986667e-03
#  3.56321456e-02 1.37995400e-02 8.61971268e-02 2.98656711e-02
#  6.82310590e-02 2.06826439e-01 1.20995967e-02 1.26662445e-03
#  3.43321889e-03 1.60561315e-01 2.86657111e-03 5.23649212e-02
#  3.76654112e-03 1.26662445e-03 1.53328222e-02 9.99966668e-05
#  2.99990000e-03 2.03326556e-03 9.99966668e-05 8.47971734e-02
#  2.76657445e-03 4.89983667e-03 7.09976334e-03] (43,) 1.0 0.20682643911869605 25
# Reduced Free Energy F: [2.30339122 3.06322977 6.94135123 5.43727383 4.11799018 3.48083727
#  4.8829631  3.12730863 4.11799018 5.09552454 3.37181853 2.76440314
#  2.90416508 3.36247267 1.38452317 5.09552454 2.17917729 3.35321334
#  2.39098928 3.94561895 1.75863179 2.70724472 0.87524314 1.93517028
#  1.10898011 0.         2.83870786 5.09552454 4.09838171 0.25320409
#  4.2787634  1.37364306 4.00572288 5.09552454 2.60188421 7.63449841
#  4.23330103 4.62223683 7.63449841 0.89161777 4.31427009 3.74267811
#  3.37181853] KT

# %%
# %matplotlib inline

fig = plt.figure(figsize=(6,4))
gs = gridspec.GridSpec(1, 1)
ax1 = plt.subplot(gs[0,0])
data1 = pd.concat([pd.read_pickle(i) for i in biceps.toolbox.get_files('biceps/NOE/*.noe')])
ax1 = data1["model"].plot.hist(alpha=0.5, bins=100, edgecolor='black', linewidth=1.2, color="b", label="Model")

# Ensure each experimental value is plotted as a separate vertical line
for exp_value in set(data1["exp"].to_numpy()):
    ax1.axvline(exp_value, c="orange", linewidth=3, label="Experiment")

handles, labels = ax1.get_legend_handles_labels()
by_label = dict(zip(labels, handles))
ax1.legend(by_label.values(), by_label.keys(), fontsize=14)
ax1.set_xlabel(r"NOE distance ($\AA$)", size=16)
ax1.set_ylabel("Counts", size=16)
ax1.axes.get_yaxis().set_ticks([])
ticks = [ax1.xaxis.get_minor_ticks(), ax1.xaxis.get_major_ticks()]
xmarks = [ax1.get_xticklabels()]
for k in range(0, len(ticks)):
    for tick in ticks[k]:
        tick.label1.set_fontsize(16)  # Corrected to tick.label1
for k in range(0, len(xmarks)):
    for mark in xmarks[k]:
        mark.set_fontsize(16)
        mark.set_rotation(0)
fig.tight_layout()
fig.savefig('biceps/histogram_of_NOE_observables.pdf', dpi=600)
plt.show()

# %%
nsteps = 5e6 
burn = 1e5
n_lambdas = 2
lambda_values = np.linspace(0.0, 1.0, n_lambdas)

# %%
#pd.DataFrame(biceps.get_restraint_options())
options = biceps.get_restraint_options(input_data)
pd.DataFrame(options)
# Out:
#        ref               sigma  use_global_ref_sigma extension  weight  \
# 0  uniform  [0.05, 20.0, 1.02]                  True       noe       1
#
#   file_fmt  log_normal              gamma
# 0   pickle       False  [0.2, 10.0, 1.01]

# %%
options[0]
# Out:
# {'ref': 'uniform',
#  'sigma': [0.05, 20.0, 1.02],
#  'use_global_ref_sigma': True,
#  'extension': 'noe',
#  'weight': 1,
#  'file_fmt': 'pickle',
#  'log_normal': False,
#  'gamma': [0.2, 10.0, 1.01]}

# %%
# Multiprocess trajectories for each $\lambda$-value with a built-in decorator
@biceps.multiprocess(iterable=lambda_values)
def mp_lambdas(lam):
    ensemble = biceps.Ensemble(lam, energies)
    ensemble.initialize_restraints(input_data, options)
    sampler = biceps.PosteriorSampler(ensemble)
    sampler.sample(nsteps=nsteps, burn=burn, print_freq=1000, verbose=False)
    filename = os.path.join(outdir,'traj_lambda%2.2f.npz'%(lam))
    sampler.traj.process_results(filename)
    biceps.toolbox.save_object(sampler, filename.replace(".npz", ".pkl"))
# Out:
# Number of CPUs: 8
# Number of processes: 2
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████  | 5000000/5100000.0 [02:44<00:03, 30442.98it/s]
# Accepted 57.64837254901961 %
#
#
# Accepted [ ...Nuisance paramters..., state] %
# Accepted [47.95992157 47.95992157  9.68845098] %
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████  | 5000000/5100000.0 [02:44<00:03, 30356.89it/s]
# Accepted 52.203980392156865 %
#
#
# Accepted [ ...Nuisance paramters..., state] %
# Accepted [47.97780392 47.97780392  4.22617647] %

# %%
convergence = biceps.Convergence(filename=os.path.join(outdir,"traj_lambda1.00.npz"), outdir=outdir)
convergence.plot_traces(figname="traces.pdf", xlim=(0, nsteps))

# %%
convergence.get_autocorrelation_curves(method="block-avg-auto", maxtau=1000, nblocks=5)

# %%
############ MBAR and Figures ###########
# %matplotlib inline
# Let's do analysis using MBAR algorithm and plot figures
A = biceps.Analysis(outdir, nstates=len(energies))
biceps.toolbox.save_object(A, "analysis_object.pkl")
#pops = A.P_dP[:,n_lambdas-1]
pops, BS = A.P_dP, A.f_df
print(f"BICePs Scores = {BS[:,0]}")
# Out:
# BICePs Scores = [0.         0.00437782]

# %%
import pickle
with open("analysis_object.pkl", 'rb') as f:
    A = pickle.load(f)

# %%
pops, BS = A.P_dP, A.f_df
pops0, pops1 = pops[:, 0], pops[:, len(lambda_values) - 1]

ntop = len(pops1)
topN_pops = pops1[np.argsort(pops1)[-ntop:]]
print(topN_pops)
topN_labels = [np.where(topN_pops[i]==pops1)[0][0] for i in range(len(topN_pops))]
print(topN_labels)

# After you have called on A = biceps.Analysis(#inputs)

legend_fontsize = 16
label_fontsize = 18

# Plot the figure with 'step' plot type, but without setting label font size to avoid errors
fig = A.plot(plottype="step", figname="BICePs_.pdf", figsize=(14, 8),
             label_fontsize=None, legend_fontsize=legend_fontsize)
ax = fig.axes[0]

# Update tick label font size using tick_params
ax.tick_params(axis='both', which='major', labelsize=label_fontsize)
ax.tick_params(axis='both', which='minor', labelsize=label_fontsize)

# Highlight specific high energy conformations
high_E_confs = [79, 21]  # Add any other indices you need
for i in high_E_confs:
    ax.text(pops0[i], pops1[i], str(i), color='r', fontsize=legend_fontsize)

# Save the figure
output_path = os.path.join(outdir, "BICePs.pdf")
fig.savefig(output_path, dpi=600)
plt.show()
# Out:
# [5.07417794e-06 8.94431365e-06 3.39045876e-05 4.84724297e-05
#  9.60586440e-05 1.39634269e-04 2.15798416e-04 2.17931575e-04
#  2.95686679e-04 3.05716141e-04 3.68713260e-04 3.77588231e-04
#  4.36642334e-04 4.99993207e-04 5.00885313e-04 5.89361596e-04
#  8.12713842e-04 9.92412938e-04 1.17840723e-03 1.32255182e-03
#  1.54251016e-03 1.89241334e-03 2.06614674e-03 2.13659398e-03
#  2.51359636e-03 2.53784129e-03 2.62390788e-03 2.81564076e-03
#  3.74630597e-03 3.90305308e-03 4.47963607e-03 6.07757383e-03
#  6.10099045e-03 7.45141319e-03 7.68624607e-03 1.16939368e-02
#  1.50518600e-02 2.11332671e-02 2.33172484e-02 2.82640918e-02
#  4.89035533e-02 5.13990781e-02 7.34216604e-01]
# [38, 35, 37, 30, 40, 4, 8, 36, 42, 2, 13, 33, 41, 27, 32, 6, 34, 12, 15, 18, 9, 3, 26, 39, 17, 31, 28, 21, 1, 25, 7, 24, 11, 0, 19, 23, 10, 14, 5, 29, 22, 16, 20]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 16
#      13 label_fontsize = 18
#      15 # Plot the figure with 'step' plot type, but without setting label font size to avoid errors
# ---> 16 fig = A.plot(plottype="step", figname="BICePs_.pdf", figsize=(14, 8),
#      17              label_fontsize=None, legend_fontsize=legend_fontsize)
#      18 ax = fig.axes[0]
#      20 # Update tick label font size using tick_params
#
# File ~/anaconda3/envs/AmberTools20/lib/python3.9/site-packages/biceps/Analysis.py:428, in Analysis.plot(self, plottype, figname, figsize, label_fontsize, legend_fontsize)
#     426 for k in range(0,len(ticks)):
#     427     for tick in ticks[k]:
# --> 428         tick.label.set_fontsize(label_fontsize)
#     429 for k in range(0,len(marks)):
#     430     for mark in marks[k]:
#
# AttributeError: 'XTick' object has no attribute 'label'

# %%
mlp = pd.concat([A.get_max_likelihood_parameters(model=i) for i in range(len(lambda_values))])
mlp.reset_index(inplace=True, drop=True)
mlp
# Out:
#    sigma_noe  gamma_noe
# 0   2.955326   1.732878
# 1   2.676730   1.681915

# %%
import uncertainties as u

pops_std = A.P_dP[:,-1]

# NOTE: Get Prior MDS populations
P = np.loadtxt('sampling/clusters_probability.dat') / 100
#np_skipped_cluster = np.array(skipped_cluster) - 1
prior_pops = P
prior_pops /= prior_pops.sum()

noe = [pd.read_pickle(i) for i in biceps.toolbox.get_files(f"biceps/NOE/*.noe")]
#  Get the ensemble average observable
noe_Exp = noe[0]["exp"].to_numpy()
noe_model = [i["model"].to_numpy() for i in noe]

noe_prior = np.array([w*noe_model[i] for i,w in enumerate(prior_pops)]).sum(axis=0)
noe_reweighted = np.array([u.ufloat(w, pops_std[i])*noe_model[i] for i,w in enumerate(pops[:,n_lambdas-1])]).sum(axis=0)

distance_labels = [f"{row[1]['atom_index1']}-{row[1]['atom_index2']}" for row in noe[0].iterrows()]
distance_label_indices = np.array([[row[1]['atom_index1'], row[1]['atom_index2']] for row in noe[0].iterrows()])

# Plot NOE data
fig = plt.figure(figsize=(12, 6))
gs = gridspec.GridSpec(1, 1)
ax1 = plt.subplot(gs[0, 0])
data = []

for i in range(len(noe_reweighted)):
    data.append({
        "index": i,
        "reweighted noe": noe_reweighted[i],
        "prior noe": noe_prior[i],
        "exp noe": noe_Exp[i] * mlp['gamma_noe'].to_numpy()[-1],
        "label": distance_labels[i]
    })

data1 = pd.DataFrame(data)
data1 = data1.sort_values(["prior noe"]).reset_index()

reweighted_vals = np.array([val.nominal_value for val in data1["reweighted noe"].to_numpy()])
reweighted_std = np.array([val.std_dev for val in data1["reweighted noe"].to_numpy()])

ax1.scatter(x=data1["label"].to_numpy(), y=data1["prior noe"].to_numpy(),
            s=45, color="orange", label="Prior", edgecolor='black')
ax1.scatter(x=data1["label"].to_numpy(), y=data1["exp noe"].to_numpy(),
            s=150, marker="_", color="k", label="Exp")
ax1.errorbar(x=data1['label'].to_numpy(), y=reweighted_vals,
             yerr=reweighted_std, fmt="o", capsize=5,
             markersize=5, markerfacecolor="c", label="BICePs",
             ecolor="k", markeredgecolor='black')

ax1.legend(fontsize=14)
ax1.set_ylabel(r"NOE distance ($\AA$)", size=16)

# Customize ticks and labels
for tick in ax1.xaxis.get_major_ticks():
    tick.label.set_fontsize(16)
for tick in ax1.yaxis.get_major_ticks():
    tick.label.set_fontsize(16)
for label in ax1.get_xticklabels():
    label.set_size(16)
    label.set_rotation(65)
for label in ax1.get_yticklabels():
    label.set_size(16)

fig.tight_layout()
fig.savefig(f"{outdir}/reweighted_NOE_observables.pdf", dpi=500)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[81], line 57
#      55 # Customize ticks and labels
#      56 for tick in ax1.xaxis.get_major_ticks():
# ---> 57     tick.label.set_fontsize(16)
#      58 for tick in ax1.yaxis.get_major_ticks():
#      59     tick.label.set_fontsize(16)
#
# AttributeError: 'XTick' object has no attribute 'label'

# %%
# !obabel -h
# Out:
# No input file or format spec or possibly a misplaced option.
# Most options must come after the input files. (-i -o -O -m can be anywhwere.)
#
# Open Babel 3.1.1 -- Feb 15 2024 -- 14:35:24
# Usage:
# obabel [-i<input-type>] <infilename> [-o<output-type>] -O<outfilename> [Options]
# Try  -H option for more information.

# %%
from openff.toolkit import Molecule, Topology
import pandas as pd
import subprocess
import os

# %%
ls
# Out:
# README.md                        res.mol2
# build_residues_from_SMILE.ipynb  residues/
# clean_smiles.csv                 residues.csv
# peptoid/                         sequences.csv
# peptoiddatabank.ipynb            smile.csv
# peptoids.csv                     test-output/

# %%
smiles_csv = 'smiles.csv'
sequences_csv = 'sequences.csv'
res_csv = 'residues.csv'
clean_smiles_csv = 'clean_smiles.csv'

clean_smiles_df = pd.read_csv(clean_smiles_csv)
res_df = pd.read_csv(res_csv)
seq_df = pd.read_csv(sequences_csv)

# %%
smile = '*N(c1cc(C)cc(C)c1)CC(=O)*'
clean_smile = smile.replace('*','')
print(clean_smile)

res = Molecule.from_smiles(clean_smile)
res.visualize()
# Out:
# N(c1cc(C)cc(C)c1)CC(=O)

# %%
peptoid_path = 'peptoid/'

# Iterate over each column
for col_name, col_data in clean_smile_df.items():
    pep_savepath = os.path.join(peptoid_path, col_name)
    os.makedirs(pep_savepath, exist_ok=True)
    print(pep_savepath)

# %%
peptoid_path = 'peptoid/'

# Iterate over each column
for col_name, col_data in clean_smile_df.items():
    pep_savepath = os.path.join(peptoid_path, col_name)
    os.makedirs(pep_savepath, exist_ok=True)
    print(pep_savepath)
    
    for index, residue in col_data.items():
        if pd.isna(residue):
            continue
        else:
            command = f"obabel -:'{residue}' -omol2 --gen3d -O {pep_savepath}/{index}.mol2"
            process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True, text=True)
            stdout, stderr = process.communicate()
        
            print(command)
            print("Standard Output:")
            print(stdout)
            print("Standard Error:")
            print(stderr)
# Out:
# peptoid/06AA1-9-A
# obabel -:'N([C@@H](C)c1ccccc1)CC(=O)' -omol2 --gen3d -O peptoid/06AA1-9-A/0.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N([C@@H](C)c1ccccc1)CC(=O)' -omol2 --gen3d -O peptoid/06AA1-9-A/1.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N([C@@H](C)c1ccccc1)CC(=O)' -omol2 --gen3d -O peptoid/06AA1-9-A/2.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N([C@@H](C)c1ccccc1)CC(=O)' -omol2 --gen3d -O peptoid/06AA1-9-A/3.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N([C@@H](C)c1ccccc1)CC(=O)' -omol2 --gen3d -O peptoid/06AA1-9-A/4.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N([C@@H](C)c1ccccc1)CC(=O)' -omol2 --gen3d -O peptoid/06AA1-9-A/5.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N([C@@H](C)c1ccccc1)CC(=O)' -omol2 --gen3d -O peptoid/06AA1-9-A/6.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N([C@@H](C)c1ccccc1)CC(=O)' -omol2 --gen3d -O peptoid/06AA1-9-A/7.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N([C@@H](C)c1ccccc1)CC(=O)' -omol2 --gen3d -O peptoid/06AA1-9-A/8.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# peptoid/13AC1-6-A
# obabel -:'N(c1cc(C)cc(C)c1)CC(=O)' -omol2 --gen3d -O peptoid/13AC1-6-A/0.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N([C@@H](C)c1cccc2ccccc21)CC(=O)' -omol2 --gen3d -O peptoid/13AC1-6-A/1.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(c1c(C)cccc1(C))CC(=O)' -omol2 --gen3d -O peptoid/13AC1-6-A/2.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N([C@@H](C)c1cccc2ccccc21)CC(=O)' -omol2 --gen3d -O peptoid/13AC1-6-A/3.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(c1ccc(F)cc1)CC(=O)' -omol2 --gen3d -O peptoid/13AC1-6-A/4.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N([C@@H](C)c1cccc2ccccc21)CC(=O)' -omol2 --gen3d -O peptoid/13AC1-6-A/5.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# peptoid/17AB1-5-A
# obabel -:'N([C@@H](C)c1cccc2ccccc21)CC(=O)' -omol2 --gen3d -O peptoid/17AB1-5-A/0.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(c1cc(C)cc(C)c1)CC(=O)' -omol2 --gen3d -O peptoid/17AB1-5-A/1.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N([C@H](C)c1cccc2ccccc21)CC(=O)' -omol2 --gen3d -O peptoid/17AB1-5-A/2.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(c1ccccc1)CC(=O)' -omol2 --gen3d -O peptoid/17AB1-5-A/3.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# peptoid/17AB2-8-A
# obabel -:'N(c1c(C)cccc1(C))CC(=O)' -omol2 --gen3d -O peptoid/17AB2-8-A/0.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N([C@H](C)c1cccc2ccccc21)CC(=O)' -omol2 --gen3d -O peptoid/17AB2-8-A/1.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(c1ccc(F)cc1)CC(=O)' -omol2 --gen3d -O peptoid/17AB2-8-A/2.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N([C@@H](C)c1cccc2ccccc21)CC(=O)' -omol2 --gen3d -O peptoid/17AB2-8-A/3.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(c1cc(C)cc(C)c1)CC(=O)' -omol2 --gen3d -O peptoid/17AB2-8-A/4.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N([C@H](C)c1cccc2ccccc21)CC(=O)' -omol2 --gen3d -O peptoid/17AB2-8-A/5.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(c1ccccc1)CC(=O)' -omol2 --gen3d -O peptoid/17AB2-8-A/6.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# peptoid/18AC2-7-A
# obabel -:'N(CCC(=O)O)CC(=O)' -omol2 --gen3d -O peptoid/18AC2-7-A/0.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(CCN)CC(=O)' -omol2 --gen3d -O peptoid/18AC2-7-A/1.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(CCO)CC(=O)' -omol2 --gen3d -O peptoid/18AC2-7-A/2.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N([C@@H](C)c1ccccc1)CC(=O)' -omol2 --gen3d -O peptoid/18AC2-7-A/3.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(CC(=O)O)CC(=O)' -omol2 --gen3d -O peptoid/18AC2-7-A/4.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(Cc1ccccc1)CC(=O)' -omol2 --gen3d -O peptoid/18AC2-7-A/5.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N[C@@H](C)C(=O)' -omol2 --gen3d -O peptoid/18AC2-7-A/6.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# peptoid/18AC1-3-A
# obabel -:'N(CC(=O)O)CC(=O)' -omol2 --gen3d -O peptoid/18AC1-3-A/0.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(Cc1ccccc1)CC(=O)' -omol2 --gen3d -O peptoid/18AC1-3-A/1.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N[C@@H](C)C(=O)' -omol2 --gen3d -O peptoid/18AC1-3-A/2.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# peptoid/19AE1-4-A
# obabel -:'N(CCN)CC(=O)' -omol2 --gen3d -O peptoid/19AE1-4-A/0.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(CCc1ccccc1)CC(=O)' -omol2 --gen3d -O peptoid/19AE1-4-A/1.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(CCN)CC(=O)' -omol2 --gen3d -O peptoid/19AE1-4-A/2.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(CCc1ccccc1)CC(=O)' -omol2 --gen3d -O peptoid/19AE1-4-A/3.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# peptoid/19AF1-10-A
# obabel -:'N(c1cc(C)cc(C)c1)CC(=O)' -omol2 --gen3d -O peptoid/19AF1-10-A/0.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(CC[N+](C(C)C)C(C)C)CC(=O)' -omol2 --gen3d -O peptoid/19AF1-10-A/1.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(c1ccc(C(C)C)cc1)CC(=O)' -omol2 --gen3d -O peptoid/19AF1-10-A/2.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(CC[N+](Cc1ccccc1)(CC)CC)CC(=O)' -omol2 --gen3d -O peptoid/19AF1-10-A/3.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(c1cc(OC)cc(OC)c1)CC(=O)' -omol2 --gen3d -O peptoid/19AF1-10-A/4.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(CC[N+](CC)(CC)CC)CC(=O)' -omol2 --gen3d -O peptoid/19AF1-10-A/5.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(c1ccc(C)cc1)CC(=O)' -omol2 --gen3d -O peptoid/19AF1-10-A/6.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(CC[N+](C)(C)C)CC(=O)' -omol2 --gen3d -O peptoid/19AF1-10-A/7.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(c1ccc(OC)cc1)CC(=O)' -omol2 --gen3d -O peptoid/19AF1-10-A/8.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
#
# obabel -:'N(CC[N+](C(C)C)C(C)C)CC(=O)' -omol2 --gen3d -O peptoid/19AF1-10-A/9.mol2
# Standard Output:
#
# Standard Error:
# 1 molecule converted
